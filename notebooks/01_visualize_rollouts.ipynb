# %% [markdown]
# # Visualize Rollouts
#
# Plot generated particle states across time.

# %%
from particle_jepa.data.toy_dataset import ToyParticleConfig, generate_toy_trajectories
from particle_jepa.visualization.particles import plot_particles

positions, _ = generate_toy_trajectories(ToyParticleConfig(num_trajectories=1))
plot_particles(positions[0, 0])
