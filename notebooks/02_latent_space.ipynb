# %% [markdown]
# # Latent Space
#
# Prototype latent trajectory visualization.

# %%
import torch

from particle_jepa.visualization.latent import plot_latent_trajectory

latents = torch.randn(16, 8).cumsum(dim=0)
plot_latent_trajectory(latents)
