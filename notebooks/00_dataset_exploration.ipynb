# %% [markdown]
# # Dataset Exploration
#
# Inspect toy particle trajectories and graph connectivity.

# %%
from particle_jepa.data.toy_dataset import ToyParticleConfig, ToyParticleDataset

dataset = ToyParticleDataset(ToyParticleConfig(num_trajectories=4))
context, future = dataset[0]
context, future
